# %%
import kagglehub
from matplotlib.pyplot import plot_date
import pandas as pd
import warnings
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\pc\.cache\kagglehub\datasets\dylanjcastillo\7k-books-with-metadata\versions\3

# %%
warnings.filterwarnings("ignore")
books = pd.read_csv(f"{path}/books.csv")
books
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
books.columns
# Out:
# Index(['isbn13', 'isbn10', 'title', 'subtitle', 'authors', 'categories',
#        'thumbnail', 'description', 'published_year', 'average_rating',
#        'num_pages', 'ratings_count'],
#       dtype='object')

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   thumbnail       6481 non-null   object
#  7   description     6548 non-null   object
#  8   published_year  6804 non-null   float64
#  9   average_rating  6767 non-null   float64
#  10  num_pages       6767 non-null   float64
#  11  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 638.6+ KB

# %%
books.describe()
# Out:
#              isbn13  published_year  average_rating    num_pages  \
# count  6.810000e+03     6804.000000     6767.000000  6767.000000
# mean   9.780677e+12     1998.630364        3.933284   348.181026
# std    6.068911e+08       10.484257        0.331352   242.376783
# min    9.780002e+12     1853.000000        0.000000     0.000000
# 25%    9.780330e+12     1996.000000        3.770000   208.000000
# 50%    9.780553e+12     2002.000000        3.960000   304.000000
# 75%    9.780810e+12     2005.000000        4.130000   420.000000
# max    9.789042e+12     2019.000000        5.000000  3342.000000
#
#        ratings_count
# count   6.767000e+03
# mean    2.106910e+04
# std     1.376207e+05
# min     0.000000e+00
# 25%     1.590000e+02
# 50%     1.018000e+03
# 75%     5.992500e+03
# max     5.629932e+06

# %%
cat_cols = books.select_dtypes(include=['object', 'category']).columns

# %%
for col in cat_cols:
    print(f"{col}: {books[col].nunique()} unique categories")

books["categories"].value_counts().reset_index().sort_values("count", ascending=False)
# Out:
# isbn10: 6810 unique categories
# title: 6398 unique categories
# subtitle: 2009 unique categories
# authors: 3780 unique categories
# categories: 567 unique categories
# thumbnail: 6481 unique categories
# description: 6474 unique categories
#                     categories  count
# 0                      Fiction   2588
# 1             Juvenile Fiction    538
# 2    Biography & Autobiography    401
# 3                      History    264
# 4           Literary Criticism    166
# ..                         ...    ...
# 562              Human cloning      1
# 563     Vietnam War, 1961-1975      1
# 564       Computer programmers      1
# 565                     Actors      1
# 496                  Surealism      1
#
# [567 rows x 2 columns]

# %%
books["categories"].value_counts().reset_index().sort_values("count", ascending=False)
# Out:
#                     categories  count
# 0                      Fiction   2588
# 1             Juvenile Fiction    538
# 2    Biography & Autobiography    401
# 3                      History    264
# 4           Literary Criticism    166
# ..                         ...    ...
# 562              Human cloning      1
# 563     Vietnam War, 1961-1975      1
# 564       Computer programmers      1
# 565                     Actors      1
# 496                  Surealism      1
#
# [567 rows x 2 columns]

# %%
books["missing_description"] = np.where(books["description"].isna(), 1, 0)

# %%
books["age_of_book"] = 2025 - books["published_year"]

# %%
columns_of_interest = ["num_pages", "age_of_book", "missing_description", "average_rating", "ratings_count"]

correlation_matrix = books[columns_of_interest].corr(method="spearman")

sns.set_theme(style="white")
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm",
                      cbar_kws={"label": "Spearman correlation"})
heatmap.set_title("Correlation heatmap")
plt.show()

# %%
book_missing = books[~(books["description"].isna()) &
      ~(books["num_pages"].isna()) &
      ~(books["average_rating"].isna()) &
      ~(books["published_year"].isna())
]

# %%
book_missing["words_in_description"] = book_missing["description"].str.split().str.len()

# %%
book_missing.shape
# Out:
# (6507, 15)

# %%
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# ...

# %%
book_missing.loc[book_missing["words_in_description"].between(1, 7), "description"]
# Out:
# 6                                               Donation.
# 11                                         Fantasy-roman.
# 77                         Nonsense rhyming story. 4 yrs+
# 104                        Library of Liberal Arts title.
# 241     Originally published: [New York]: Clarion Book...
#                               ...
# 6704      Accessible and affordable illustrated biography
# 6721                                              Horror.
# 6726       Presents two complete novels from Henry James.
# 6757                          Audio Book- unabriged on CD
# 6794                                 源氏物語54帖、「宮田切り絵」の真骨頂。
# Name: description, Length: 94, dtype: object

# %%
book_missing.loc[book_missing["words_in_description"].between(0, 10), "description"]
# Out:
# 6                                               Donation.
# 11                                         Fantasy-roman.
# 77                         Nonsense rhyming story. 4 yrs+
# 104                        Library of Liberal Arts title.
# 241     Originally published: [New York]: Clarion Book...
#                               ...
# 6721                                              Horror.
# 6726       Presents two complete novels from Henry James.
# 6757                          Audio Book- unabriged on CD
# 6794                                 源氏物語54帖、「宮田切り絵」の真骨頂。
# 6795    Book Of Five Rings is a Kodansha International...
# Name: description, Length: 157, dtype: object

# %%
book_missing.loc[book_missing["words_in_description"].between(0, 10), "description"]
# Out:
# 6                                               Donation.
# 11                                         Fantasy-roman.
# 77                         Nonsense rhyming story. 4 yrs+
# 104                        Library of Liberal Arts title.
# 241     Originally published: [New York]: Clarion Book...
#                               ...
# 6721                                              Horror.
# 6726       Presents two complete novels from Henry James.
# 6757                          Audio Book- unabriged on CD
# 6794                                 源氏物語54帖、「宮田切り絵」の真骨頂。
# 6795    Book Of Five Rings is a Kodansha International...
# Name: description, Length: 157, dtype: object

# %%
book_missing_10_words = book_missing[book_missing["words_in_description"] >= 10]

# %%
book_missing_10_words["title_and_subtitle"] = (
    np.where(book_missing_10_words["subtitle"].isna(), book_missing_10_words["title"],
             book_missing_10_words[["title", "subtitle"]].astype(str).agg(": ".join, axis=1))
)

# %%
book_missing_10_words["tagged_description"] = book_missing_10_words[["isbn13", "description"]].astype(str).agg(" ".join, axis=1)

# %%
(
    book_missing_10_words
    .drop(["subtitle", "missing_description", "age_of_book", "words_in_description"], axis=1)
    .to_csv("books_cleaned.csv", index = False)
)

# %%
book_missing_10_words
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# ...
